# %% [markdown]
# <a href="https://colab.research.google.com/github/codingsohyun/multimodal-web-project/blob/main/sentiment_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/sentiment_data.csv', encoding='cp949')

# %%
data.head()
# Out:
#    Column1                                  Text Emotion Emotion_eng
# 0        0             어머니가 이제 내 세뱃돈을 대신 관리해주신대.      불안         NaN
# 1        1             요즘 아빠가 편찮으셔서 더 악화되실까 무서워.      불안         NaN
# 2        2  나는 공부에 흥미가 없는데 부모님이 너무나도 재촉을 해서 힘들어.      불안         NaN
# 3        3         첫 직장이 중요하다고 하니 진로를 정하기 조심스러워.      불안         NaN
# 4        4      부모님이 내가 공부를 대충 한다고 하셨어. 진짜 너무하셔!      불안         NaN

# %%
# Emotion 컬럼 내 속성 파악
data['Emotion'].value_counts()
# Out:
# 성취/만족     2143
# 쏘쏘        2000
# 분노        1800
# 즐거움/신남    1733
# 행복/기쁨     1724
# 불안        1700
# 상처        1700
# 슬픔        1700
# 당황        1700
# 감사        1470
# 놀람        1449
# Name: Emotion, dtype: int64
